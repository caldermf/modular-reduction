# %%
T = CartanType(['A', 5])
W = WeylGroup(T,prefix="s")
[s1,s2,s3,s4,s5] = W.simple_reflections()

n = len(W.simple_reflections())
e = s1^2
w0 = W.long_element()
S.<q> = LaurentPolynomialRing(QQ)
KL = KazhdanLusztigPolynomial(W,q)

import json

# %%
#import json

#data = {"hello" : "at all", "cheers" : "nuts"}
#json.dump( data, open( "file_name.json", 'w' ) )

# %%
#data = {}
#data = json.load( open( "file_name.json" ) )
#print(data)
# Out:
# {'hello': 'at all', 'cheers': 'nuts'}

# %%
kl_dict = {}
for i in range(len(W)):
    w = W[i]
    print(i + 1, "out of", len(W), end='\r')
    interv = W.bruhat_interval(e, w)
    for y in interv:
        kl_dict[str((y, w))] = int(KL.P(y, w)(1))
print(kl_dict)
# Out:
# 720 out of 720
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
json.dump( kl_dict, open( "a5.json", 'w' ) )

# %%
print(kl_dict)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
