# %%
T = CartanType(['A', 5])
W = WeylGroup(T,prefix="s")
[s1, s2, s3, s4, s5] = W.simple_reflections()

WCR = WeylCharacterRing(T, style="coroots", base_ring=QQ)
R = WeightRing(WCR)
# EXPI MODIFIED, THIS CODE ONLY WORKS IN TYPE A
f = [w.coerce_to_sl() for w in WCR.fundamental_weights()]

n = len(W.simple_reflections())
e = s1^2
w0 = W.long_element()
S.<q> = LaurentPolynomialRing(QQ)
KL = KazhdanLusztigPolynomial(W,q)
q = 29

def Iw(w):
    a = []
    for i in range(1, n+1):
        if w.has_right_descent(i):
            a.append(i)
    return a

def Iwc(w):
    a = []
    for i in range(1, n+1):
        if not w.has_right_descent(i):
            #a.append(W.simple_reflections()[i])
            a.append(i)
    return a

def expI(l):
    a = R.one()
    for i in l:
        a = a * R(f[i-1])
    return a

def esub(w):
    return expI(Iw(w)).weyl_group_action(w)

def eqsub(w):
    return expI(Iw(w)).weyl_group_action(w).scale(q)

def esup(w):
    return (-1)^(w.length())*expI(Iwc(w)).weyl_group_action(w)

def Iweight(w):
    wgt = 0
    for a in Iw(w):
        wgt += f[a-1]
    return wgt

rho = Iweight(w0)

def weightpairing(l):
    a = WCR.dot_reduce(l)
    if a[0] == 0:
        return 0
    else:
        return a[0]*WCR(a[1])

def woke_weightpairing(l):
    a = WCR.dot_reduce(l - rho)
    if a[0] == 0:
        return 0
    else:
        return a[0]*WCR(a[1])

def inprod(a, b):
    da = dict(a)
    db = dict(b)
    t = 0
    for v in da:
        for u in db:
            t += da[v] * db[u] * v.inner_product(u)
    return t

def rootprod(a, b):
    return 2*inprod(a,b)/inprod(b,b)
    
def dom(a):
    for b in R.simple_roots():
        if rootprod(a, R(b)) < 0:
            return False
    return True

def hom(a, b):
    return woke_pairing(b, R(rho)*a.scale(-1))

def woke_pairing(a, b):
    #takes two elements of R and gives you an element of WCR
    d = dict(R(a*b))
    r = 0
    for l in d:
        r += d[l]*woke_weightpairing(l)
    return r

def pairing(a, b):
    #takes two elements of R and gives you an element of WCR
    a = a.scale(-1)
    d = dict(R(a*b))
    r = 0
    for l in d:
        r += d[l]*weightpairing(l)
    return r

def norma(a):
    k = list(dict(a).keys())
    return R(k[0])

def check_dual(d1, d2):
    for w in W:
        for y in W:
            a = woke_pairing(d1[w], d2[y])
            if w != y and a != 0:
                print("Fails at", w, y)
            elif w == y and a != 1:
                print("Fails at", w, y)
    print("Checked.")

d_sub = {}
d_sup = {}
d_qsub = {}
for i in range(len(W)):
    d_sub[i] = esub(W[i])

# %%
element_list = [[5, 4, 3, 2, 1, 5, 4, 3, 2, 5, 4, 3, 5, 4, 5], [5, 4, 3, 2, 1, 5, 4, 
  3, 2, 5, 4, 3, 5, 4], [5, 4, 3, 2, 1, 5, 4, 3, 2, 5, 4, 3, 4, 
  5], [5, 4, 3, 2, 1, 5, 4, 3, 2, 4, 3, 5, 4, 5], [5, 4, 3, 2, 1, 4, 
  3, 2, 5, 4, 3, 5, 4, 5], [4, 3, 2, 1, 5, 4, 3, 2, 5, 4, 3, 5, 4, 
  3, 5, 4], [3, 2, 3, 5], [3, 2, 1, 5], [1, 3, 2, 5], [2, 3, 5, 
  4], [2, 1, 3, 5], [2, 1, 2, 5], [1, 2, 3, 5], [4, 3, 5, 4], [4, 3, 
  2, 5], [1, 4, 3, 5], [2, 4, 3, 5], [2, 1, 4, 5], [1, 2, 4, 5], [4, 
  3, 4, 5], [4, 3, 2, 4], [1, 4, 3, 4], [4, 3, 2, 3], [4, 3, 2, 
  1], [1, 4, 3, 2], [2, 4, 3, 4], [2, 1, 4, 3], [2, 1, 2, 4], [1, 2, 
  4, 3], [3, 2, 4, 5], [1, 3, 4, 5], [3, 2, 4, 3], [3, 2, 1, 4], [1, 
  3, 2, 4], [3, 2, 3, 4], [3, 2, 1, 3], [3, 2, 1, 2], [1, 3, 2, 
  3], [2, 3, 4, 5], [2, 1, 3, 4], [2, 1, 3, 2], [2, 1, 2, 3], [1, 2, 
  3, 4], [5, 4, 5], [5, 4, 3], [2, 5, 4], [1, 5, 4], [3, 5, 4], [3, 
  2, 5], [1, 3, 5], [2, 3, 5], [2, 1, 5], [1, 2, 5], [4, 3, 5], [2, 
  4, 5], [1, 4, 5], [4, 3, 4], [4, 3, 2], [1, 4, 3], [2, 4, 3], [2, 
  1, 4], [1, 2, 4], [3, 4, 5], [3, 2, 4], [1, 3, 4], [3, 2, 3], [3, 
  2, 1], [1, 3, 2], [2, 3, 4], [2, 1, 3], [2, 1, 2], [1, 2, 3], [5, 
  4], [3, 5], [2, 5], [1, 5], [4, 5], [4, 3], [2, 4], [1, 4], [3, 
  4], [3, 2], [1, 3], [2, 3], [2, 1], [1, 2], [5], [4], [3], [2], [1],
  []]

Wo = []

S = list(W.simple_reflections())
for i in range(len(element_list)):
    a = s1*s1
    for j in range(len(element_list[i])):
        a = a * S[element_list[i][j]-1]
    Wo.append(a)

Wo.reverse()
print(Wo)
print(len(Wo))
# Out:
# [1, s1, s2, s3, s4, s5, s1*s2, s2*s1, s2*s3, s3*s1, s3*s2, s3*s4, s4*s1, s4*s2, s4*s3, s4*s5, s5*s1, s5*s2, s5*s3, s5*s4, s1*s2*s3, s1*s2*s1, s2*s3*s1, s2*s3*s4, s3*s1*s2, s3*s2*s1, s2*s3*s2, s3*s4*s1, s3*s4*s2, s3*s4*s5, s4*s1*s2, s4*s2*s1, s4*s2*s3, s4*s3*s1, s4*s3*s2, s3*s4*s3, s4*s5*s1, s4*s5*s2, s4*s5*s3, s5*s1*s2, s5*s2*s1, s5*s2*s3, s5*s3*s1, s5*s3*s2, s5*s3*s4, s5*s4*s1, s5*s4*s2, s5*s4*s3, s4*s5*s4, s1*s2*s3*s4, s1*s2*s3*s1, s2*s3*s1*s2, s2*s3*s4*s1, s2*s3*s4*s5, s1*s2*s3*s2, s3*s1*s2*s1, s2*s3*s2*s1, s2*s3*s4*s2, s3*s4*s1*s2, s3*s4*s2*s1, s3*s4*s2*s3, s3*s4*s5*s1, s3*s4*s5*s2, s4*s1*s2*s3, s4*s1*s2*s1, s4*s2*s3*s1, s2*s3*s4*s3, s4*s3*s1*s2, s4*s3*s2*s1, s4*s2*s3*s2, s3*s4*s3*s1, s3*s4*s3*s2, s3*s4*s5*s3, s4*s5*s1*s2, s4*s5*s2*s1, s4*s5*s2*s3, s4*s5*s3*s1, s4*s5*s3*s2, s4*s5*s3*s4, s5*s1*s2*s3, s5*s1*s2*s1, s5*s2*s3*s1, s5*s2*s3*s4, s5*s3*s1*s2, s5*s3*s2*s1, s5*s2*s3*s2, s5*s3*s4*s1, s5*s3*s4*s2, s3*s4*s5*s4, s5*s4*s1*s2, s5*s4*s2*s1, s5*s4*s2*s3, s5*s4*s3*s1, s5*s4*s3*s2, s
# ...

# %%
Woi = []
for w in Wo:
    Woi.append(w.inverse())
Wo = Woi

# %%
print(len(Woi))
# Out:
# 720

# %%
def wt(a):
    #Takes in some R(1,1) and spits out the raw weight, i.e. defined by R(wt(R(a,b))) = R(a,b).
    return list((dict(a)).keys())[0]

def pchar(a):
    domele_w_pairs = [
        (a.weyl_group_action(y), y) for y in W if dom(a.weyl_group_action(y))
    ]
    domele, w = min(domele_w_pairs, key=lambda pair: pair[1].length())

    # Reverse w
    w_inv = w.inverse()

    redword = w_inv.reduced_word()
    return WCR.demazure_character(wt(domele), word=redword)

#ok p is DONE! NICE
def p(w):
    return pchar(esub(w).scale(-1)).scale(-1)

def buildxdict():
    xdict = {}
    for i in range(len(Wo)):
        print(f"\r{i}", end="", flush=True)
        currentxw = p(Wo[i])
        for j in range(i):
            currentxw = currentxw - hom(xdict[Wo[j]], currentxw)*xdict[Wo[j]]
        xdict[Wo[i]] = currentxw
    return xdict
                
xdict = buildxdict()
print(xdict)
# Out:
# 147
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 31
#      28         xdict[Wo[i]] = currentxw
#      29     return xdict
# ---> 31 xdict = buildxdict()
#      32 print(xdict)
#
# Cell In[6], line 27, in buildxdict()
#      25     currentxw = p(Wo[i])
#      26     for j in range(i):
# ---> 27         currentxw = currentxw - hom(xdict[Wo[j]], currentxw)*xdict[Wo[j]]
#      28     xdict[Wo[i]] = currentxw
#      29 return xdict
#
# Cell In[2], line 88, in hom(a, b)
#      87 def hom(a, b):
# ---> 88     return woke_pairing(b, R(rho)*a.scale(-Integer(1)))
#
# Cell In[2], line 92, in woke_pairing(a, b)
#      90 def woke_pairing(a, b):
#      91     #takes two elements of R and gives you an element of WCR
# ---> 92     d = dict(R(a*b))
#      93     r = Integer(0)
#      94     for l in d:
#
# ...

# %%
svka3_hom_dual = {s1*s2*s3*s1*s2*s1: a3(1,1,1), s1*s2*s3*s1*s2: -a3(1,1,0) - a3(1,0,2) - a3(0,2,1), s1*s2*s3*s2*s1: -a3(0,2,0) - a3(0,1,2) - a3(1,0,1) - a3(2,1,0) - a3(2,0,2), s2*s3*s1*s2*s1: -a3(0,1,1) - a3(2,0,1) - a3(1,2,0), s1*s2*s3*s2: a3(0,2,0) + a3(0,1,2) + a3(1,0,1), s1*s2*s3*s1: a3(1,1,0) + a3(1,0,2), s2*s3*s2*s1: a3(0,1,1) + a3(2,0,1), s2*s3*s1*s2: a3(0,1,0) + a3(0,0,2) + a3(-1,2,1) + a3(2,0,0) + a3(2,-1,2) + a3(1,2,-1) + 3*a3(1,1,1) + a3(0,3,0), s3*s1*s2*s1: a3(0,2,0) + a3(1,0,1) + a3(2,1,0), s2*s3*s2: -a3(0,1,1), s1*s2*s3: -a3(1,0,0) - a3(1,-1,2) - a3(0,2,-1) - 2*a3(0,1,1) - a3(0,0,3) - a3(2,0,1), s2*s3*s1: -a3(0,1,0) - a3(0,0,2) - a3(2,0,0) - a3(2,-1,2) - a3(1,1,1), s3*s1*s2: -a3(0,2,0) - a3(1,0,1), s1*s2*s1: -a3(1,1,0), s3*s2*s1: -a3(0,0,1) - a3(-1,2,0) - a3(2,-1,1) - 2*a3(1,1,0) - a3(1,0,2) - a3(3,0,0), s2*s3: a3(0,1,0) + a3(0,0,2), s3*s1: a3(1,0,1), s3*s2: a3(0,0,1) + a3(-1,2,0) + a3(1,1,0), s1*s2: a3(1,0,0) + a3(0,2,-1) + a3(0,1,1), s2*s1: a3(0,1,0) + a3(2,0,0), s3: -a3(0,0,1), s2: -a3(0,1,0), s1: -a3(1,0,0), s1*s1: a3(0,0,0)}
#for w in W:
#    for y in W:
#        print(hom(svka3_hom_dual[y], svka3[w]), w == y)

svka3_dual = {s1*s2*s3*s1*s2*s1: a3(0,0,0), s1*s2*s3*s1*s2: -a3(1,-1,0) - a3(0,1,-1) - a3(0,0,1), s1*s2*s3*s2*s1: -a3(-1,1,-1) - a3(-1,0,1) - a3(1,0,-1) - a3(1,-1,1) - a3(0,1,0), s2*s3*s1*s2*s1: -a3(0,-1,1) - a3(-1,1,0) - a3(1,0,0), s1*s2*s3*s2: a3(1,0,-1) + a3(1,-1,1) + a3(0,1,0), s1*s2*s3*s1: a3(0,1,-1) + a3(0,0,1), s2*s3*s2*s1: a3(-1,1,0) + a3(1,0,0), s2*s3*s1*s2: 3*a3(0,0,0) + a3(2,-1,0) + a3(1,1,-1) + a3(1,0,1) + a3(1,-2,1) + a3(-1,2,-1) + a3(-1,1,1) + a3(0,-1,2), s3*s1*s2*s1: a3(-1,0,1) + a3(1,-1,1) + a3(0,1,0), s2*s3*s2: -a3(1,0,0), s1*s2*s3: -a3(-1,1,0) - a3(1,1,-2) - 2*a3(1,0,0) - a3(1,-1,2) - a3(0,2,-1) - a3(0,1,1), s2*s3*s1: -a3(0,0,0) - a3(1,1,-1) - a3(1,0,1) - a3(-1,2,-1) - a3(-1,1,1), s3*s1*s2: -a3(1,-1,1) - a3(0,1,0), s1*s2*s1: -a3(0,0,1), s3*s2*s1: -a3(-2,1,1) - a3(0,1,-1) - 2*a3(0,0,1) - a3(-1,2,0) - a3(2,-1,1) - a3(1,1,0), s2*s3: a3(1,1,-1) + a3(1,0,1), s3*s1: a3(0,1,0), s3*s2: a3(0,0,1) + a3(2,-1,1) + a3(1,1,0), s1*s2: a3(1,0,0) + a3(1,-1,2) + a3(0,1,1), s2*s1: a3(1,0,1) + a3(-1,1,1), s3: -a3(1,1,0), s2: -a3(1,0,1), s1: -a3(0,1,1), s1*s1: a3(1,1,1)}

# %%
print(xdict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(xdict)
#
# NameError: name 'xdict' is not defined

# %%
shifted_x = {}

for w in Wo:
    #print(w)
    #print(p(w.inverse()), "p(w)")
    #print(svka3_dual[w]) #, "xdict")
    #print((-1)^(w.length())*svka3[w0*w].scale(-1)) #, "svk")
    shifted_x[w] = (-1)^(w.length())*xdict[w*w0].scale(-1)
    #print()

print("Defined shifted x dictionary:")
print()
print(shifted_x)
# Out:
# Defined shifted x dictionary:
#
# ...

# %%
# PROOF THAT P IS CORRECT
# KEEP THIS
"""
# plist is from Mathematica
plist = [R(1, 1, 1), R(0, 1, 1), R(1, 0, 1), R(1, 1, 0), 
 R(-1, 1, 1) + R(1, 0, 1), R(0, 1, 1) + R(1, -1, 2), 
 R(1, 1, 0) + R(2, -1, 1), R(0, 1, 0), R(1, 0, 1) + R(1, 1, -1), 
 R(-2, 1, 1) + R(-1, 2, 0) + R(0, 0, 1) + R(1, 1, 0) + R(2, -1, 1), 
 R(0, 0, 1), R(0, 1, 0) + R(1, -1, 1), 
 R(-1, 1, 1) + R(-1, 2, -1) + R(1, 0, 1) + R(1, 1, -1), 
 R(0, 1, 1) + R(0, 2, -1) + R(1, -1, 2) + R(1, 0, 0) + R(1, 1, -2), 
 R(1, 0, 0), R(-1, 0, 1) + R(0, 1, 0) + R(1, -1, 1), 
 R(-1, 1, 1) + R(-1, 2, -1) + R(0, -1, 2) + R(0, 0, 0) + R(1, -2, 1) +
   R(1, 0, 1) + R(1, 1, -1) + R(2, -1, 0), R(-1, 1, 0) + R(1, 0, 0), 
 R(0, 0, 1) + R(0, 1, -1), R(0, 1, 0) + R(1, -1, 1) + R(1, 0, -1), 
 R(-1, 1, 0) + R(0, -1, 1) + R(1, 0, 0), 
 R(-1, 0, 1) + R(-1, 1, -1) + R(0, 1, 0) + R(1, -1, 1) + R(1, 0, -1), 
 R(0, 0, 1) + R(0, 1, -1) + R(1, -1, 0), R(0, 0, 0)]

Wo.reverse()
print(Wo)
print()
for i in range(len(Wo)):
    print(w)
    print(plist[i])
    print(p(Wo[i].inverse()).scale(-1))
    print()

Wo.reverse()
"""
print("Hello at all. This cell does nothing and it's all commented out rn.")
# Out:
# Hello at all. This cell does nothing and it's all commented out rn.

# %%
check_dual(xdict, shifted_x)
# Out:
# Checked.

# %%
q = 29
totalsum = 0
for w in Wo:
    totalsum += woke_pairing(xdict[w].scale(q), shifted_x[w])
print(totalsum)
# Out:
# B3(0,0,0) - B3(0,0,24) - 2*B3(0,1,24) + 3*B3(0,0,26) + 2*B3(1,0,26) + 7*B3(0,0,28) + B3(25,0,0) - B3(26,0,0) + B3(0,26,0) - 5*B3(27,0,0) + 2*B3(1,26,0) + 3*B3(0,27,0) - 3*B3(0,26,2) + 5*B3(28,0,0) + 4*B3(1,27,0) + 11*B3(0,28,0) + B3(27,0,26) + 2*B3(26,0,28) + B3(28,0,26) + 3*B3(27,1,26) + 5*B3(27,0,28) + B3(0,27,28) + 4*B3(29,0,26) + 11*B3(28,0,28) + 5*B3(0,28,28) + B3(28,27,0) + 2*B3(27,28,0) + 2*B3(29,27,0) + 7*B3(28,28,0) + B3(28,28,28)
