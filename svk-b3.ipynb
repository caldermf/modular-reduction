# %%
T = CartanType(['B', 3])
W = WeylGroup(T,prefix="s")
[s1, s2, s3] = W.simple_reflections()

WCR = WeylCharacterRing(T, style="coroots", base_ring=QQ)
R = WeightRing(WCR)
# EXPI MODIFIED, THIS CODE ONLY WORKS IN TYPE A
f = [w.coerce_to_sl() for w in WCR.fundamental_weights()]

n = len(W.simple_reflections())
e = s1^2
w0 = W.long_element()
S.<q> = LaurentPolynomialRing(QQ)
KL = KazhdanLusztigPolynomial(W,q)
q = 29

def Iw(w):
    a = []
    for i in range(1, n+1):
        if w.has_right_descent(i):
            a.append(i)
    return a

def Iwc(w):
    a = []
    for i in range(1, n+1):
        if not w.has_right_descent(i):
            #a.append(W.simple_reflections()[i])
            a.append(i)
    return a

def expI(l):
    a = R.one()
    for i in l:
        a = a * R(f[i-1])
    return a

def Cpsub_on_wr_element(w, v):
    interv = W.bruhat_interval(e, w)
    s = 0
    for y in interv:
        a = v.weyl_group_action(y)
        s += int(KL.P(y, w)(1)) * a
    return s

def Cpsup_on_wr_element(w, v):
    interv = W.bruhat_interval(e, w0*w)
    s = 0
    for y in interv:
        a = v.weyl_group_action(w0*y)
        s += int(KL.P(y, w0*w)(1)) * a
    return s

def fsub(w):
    return Cpsub_on_wr_element(w, expI(Iwc(w)))

def qfsub(w):
    return Cpsub_on_wr_element(w, expI(Iwc(w)).scale(q))

def fsup(w):
    return Cpsup_on_wr_element(w, expI(Iw(w)))

invols = []
for w in W:
    if w*w == e:
        invols.append(w)

def Iweight(w):
    wgt = 0
    for a in Iw(w):
        wgt += f[a-1]
    return wgt

rho = Iweight(w0)

def weightpairing(l):
    a = WCR.dot_reduce(l)
    if a[0] == 0:
        return 0
    else:
        return a[0]*WCR(a[1])

def pairing(a, b):
    #takes two elements of R and gives you an element of WCR
    b = b.scale(-1)
    d = dict(R(a*b))
    r = 0
    for l in d:
        r += d[l]*weightpairing(l)
    return r

def woke_weightpairing(l):
    a = WCR.dot_reduce(l - rho)
    if a[0] == 0:
        return 0
    else:
        return a[0]*WCR(a[1])

def woke_pairing(a, b):
    #takes two elements of R and gives you an element of WCR
    d = dict(R(a*b))
    r = 0
    for l in d:
        r += d[l]*woke_weightpairing(l)
    return r

def pairing(a, b):
    #takes two elements of R and gives you an element of WCR
    a = a.scale(-1)
    d = dict(R(a*b))
    r = 0
    for l in d:
        r += d[l]*weightpairing(l)
    return r

invols = []
for w in W:
    if w*w == e:
        invols.append(w)

d_sub = {}
d_sup = {}

for i in range(len(W)):
    print(i + 1, "out of", len(W), end='\r')
    d_sub[i] = fsub(W[i])
    d_sup[i] = fsup(W[i])

print("Setup done, f_w, f^w are defined.")
# Out:
# Setup done, f_w, f^w are defined.

# %%
svk = [R(-1, -1, -1), R(0, -1, -1), R(-1, 0, -1), R(-1, -1, 0), 
 R(-1, 0, -1) + R(1, -1, -1), 
 R(-2, 1, -1) + R(-1, -1, 1) + R(-1, 0, -1) + R(-1, 1, -3) + 
  R(0, -1, -1) + R(0, 0, -1), 
 R(-2, 0, 0) + R(-2, 1, -2) + R(-1, -1, 0) + R(-1, 0, 0) + 
  R(-1, 1, -2) + R(0, -1, 0) + R(0, 0, -2), R(0, -1, 0), 
 R(-1, -1, 1) + R(-1, 0, -1), 
 R(-2, 0, 0) + R(-2, 1, -2) + R(-1, -1, 0) + 2*R(-1, 0, 0) + 
  R(-1, 1, -2) + R(0, -2, 2) + 3*R(0, -1, 0) + 2*R(0, 0, -2) + 
  R(1, -2, 0) + 2*R(1, -1, 0) + R(1, 0, -2) + R(2, -2, 0) + 
  R(2, -1, -2), R(0, 0, -1), R(-1, 0, 0) + R(-1, 1, -2) + R(0, -1, 0),
  R(-2, 1, -1) + R(-1, -1, 1) + R(-1, 0, -1), 
 R(-1, -1, 1) + R(-1, 0, -1) + R(0, -1, 1) + R(0, 0, -1) + 
  R(1, -2, 1) + R(1, -1, -1), 
 R(-2, 0, 1) + R(-2, 1, -1) + R(-1, -2, 3) + 2*R(-1, -1, 1) + 
  2*R(-1, 0, -1) + R(-1, 1, -3) + R(0, -2, 1) + R(0, -1, -1) + 
  R(0, -1, 1) + R(0, 0, -1), 
 R(-2, -1, 2) + R(-2, 0, 0) + R(-2, 1, -2) + R(-1, -1, 0) + 
  R(-1, -1, 2) + 2*R(-1, 0, 0) + R(-1, 1, -2) + R(0, -2, 2) + 
  2*R(0, -1, 0) + R(0, 0, -2), 
 R(-2, 1, -1) + R(-1, -1, 1) + R(-1, 0, -1) + R(0, -1, 1) + 
  2*R(0, 0, -1) + R(1, -2, 1) + R(1, -1, -1) + R(2, -1, -1), 
 R(-1, 0, 0) + R(-1, 1, -2) + R(0, -1, 0) + R(0, 0, 0) + R(0, 1, -2) +
   R(1, -1, 0) + R(1, 0, -2), 
 R(-2, 1, -1) + R(-1, -1, 1) + R(-1, 0, -1) + R(-1, 0, 1) + 
  2*R(-1, 1, -1) + R(-1, 2, -3) + 2*R(0, -1, 1) + 3*R(0, 0, -1) + 
  R(0, 1, -3) + R(1, -2, 1) + R(1, -1, -1) + R(1, 0, -1), 
 R(-3, 2, -1) + 2*R(-2, 0, 1) + 2*R(-2, 1, -1) + R(-2, 2, -3) + 
  R(-1, -2, 3) + 2*R(-1, -1, 1) + 3*R(-1, 0, -1) + R(-1, 1, -3) + 
  R(-1, 1, -1) + R(0, -2, 1) + R(0, -1, -1) + R(0, -1, 1) + 
  R(0, 0, -1), 
 R(-2, -1, 2) + R(-2, 0, 0) + R(-2, 1, -2) + R(-1, -1, 0) + 
  R(-1, -1, 2) + 3*R(-1, 0, 0) + R(-1, 1, -2) + 2*R(0, -2, 2) + 
  3*R(0, -1, 0) + R(0, -1, 2) + 2*R(0, 0, -2) + R(0, 0, 0) + 
  R(0, 1, -2) + R(1, -2, 0) + R(1, -2, 2) + 3*R(1, -1, 0) + 
  R(1, 0, -2) + R(2, -3, 2) + R(2, -2, 0) + R(2, -1, -2), 
 R(0, -1, 1) + R(0, 0, -1), 
 R(-1, -1, 2) + R(-1, 0, 0) + R(-1, 1, -2) + R(0, -1, 0), R(-1, 0, 0),
  R(-3, 2, -1) + 2*R(-2, 0, 1) + 2*R(-2, 1, -1) + R(-2, 2, -3) + 
  R(-1, -2, 3) + 2*R(-1, -1, 1) + R(-1, -1, 3) + 3*R(-1, 0, -1) + 
  3*R(-1, 0, 1) + R(-1, 1, -3) + 6*R(-1, 1, -1) + 2*R(-1, 2, -3) + 
  R(0, -2, 1) + R(0, -2, 3) + R(0, -1, -1) + 7*R(0, -1, 1) + 
  8*R(0, 0, -1) + 2*R(0, 0, 1) + 3*R(0, 1, -3) + 2*R(0, 1, -1) + 
  R(0, 2, -3) + R(1, -3, 3) + 2*R(1, -2, 1) + R(1, -2, 3) + 
  3*R(1, -1, -1) + 3*R(1, -1, 1) + R(1, 0, -3) + 6*R(1, 0, -1) + 
  2*R(1, 1, -3) + 2*R(2, -2, 1) + 2*R(2, -1, -1) + R(2, 0, -3) + 
  R(3, -1, -1), 
 R(-2, 1, -1) + R(-1, -1, 1) + R(-1, 0, -1) + R(-1, 0, 1) + 
  2*R(-1, 1, -1) + R(-1, 2, -3) + 2*R(0, -1, 1) + 4*R(0, 0, -1) + 
  R(0, 1, -3) + R(0, 1, -1) + R(1, -2, 1) + R(1, -1, -1) + 
  R(1, -1, 1) + 2*R(1, 0, -1) + R(1, 1, -3) + R(2, -1, -1), 
 R(-3, 1, 0) + R(-2, -1, 2) + R(-2, 0, 0) + R(-2, 0, 2) + 
  R(-2, 1, -2) + 2*R(-2, 1, 0) + 2*R(-2, 2, -2) + R(-1, -1, 0) + 
  2*R(-1, -1, 2) + 7*R(-1, 0, 0) + R(-1, 0, 2) + 3*R(-1, 1, -2) + 
  3*R(-1, 1, 0) + R(-1, 2, -4) + 2*R(-1, 2, -2) + R(-1, 3, -4) + 
  2*R(0, -2, 2) + 3*R(0, -1, 0) + 3*R(0, -1, 2) + 3*R(0, 0, -2) + 
  7*R(0, 0, 0) + 7*R(0, 1, -2) + R(0, 2, -4) + R(1, -2, 0) + 
  2*R(1, -2, 2) + 7*R(1, -1, 0) + 4*R(1, 0, -2) + R(1, 0, 0) + 
  R(1, 1, -4) + R(1, 1, -2) + R(2, -3, 2) + R(2, -2, 0) + 
  R(2, -1, -2) + R(2, -1, 0) + R(2, 0, -2), 
 R(-1, 1, -1) + R(0, -1, 1) + R(0, 0, -1), R(-1, 0, 0) + R(1, -1, 0), 
 R(-1, -1, 2) + 2*R(-1, 0, 0) + R(-1, 1, -2) + R(0, -1, 0) + 
  R(0, -1, 2) + 2*R(0, 0, 0) + R(0, 1, -2) + R(1, -2, 2) + 
  2*R(1, -1, 0) + R(1, 0, -2), 
 R(-2, 0, 1) + R(-2, 1, -1) + R(-1, -1, 1) + R(-1, -1, 3) + 
  R(-1, 0, -1) + 3*R(-1, 0, 1) + 3*R(-1, 1, -1) + R(-1, 2, -3) + 
  R(0, -2, 3) + 4*R(0, -1, 1) + 4*R(0, 0, -1) + R(0, 1, -3) + 
  R(1, -2, 1) + R(1, -1, -1) + R(1, -1, 1) + R(1, 0, -1), 
 R(-2, 1, 0) + R(-1, -1, 2) + R(-1, 0, 0) + R(-1, 1, -2) + 
  R(0, -1, 0) + R(0, 0, 0), 
 R(-1, 1, -1) + R(0, -1, 1) + R(0, 0, -1) + R(1, 0, -1), 
 R(-1, 0, 0) + R(0, 0, 0) + R(0, 1, -2) + R(1, -1, 0), 
 R(-2, 1, 0) + R(-1, -1, 2) + 2*R(-1, 0, 0) + R(-1, 1, -2) + 
  R(-1, 1, 0) + R(-1, 2, -2) + R(0, -1, 0) + R(0, -1, 2) + 
  4*R(0, 0, 0) + 2*R(0, 1, -2) + R(1, -2, 2) + 2*R(1, -1, 0) + 
  R(1, 0, -2), 
 R(-2, 1, 0) + R(-1, -1, 2) + 2*R(-1, 0, 0) + R(-1, 1, -2) + 
  R(0, -1, 0) + R(0, -1, 2) + 3*R(0, 0, 0) + R(0, 1, -2) + 
  R(1, -2, 2) + 2*R(1, -1, 0) + R(1, 0, -2) + R(2, -1, 0), 
 R(-2, 0, 1) + R(-2, 1, -1) + R(-1, -1, 1) + R(-1, -1, 3) + 
  R(-1, 0, -1) + 3*R(-1, 0, 1) + 3*R(-1, 1, -1) + R(-1, 2, -3) + 
  R(0, -2, 3) + 5*R(0, -1, 1) + 5*R(0, 0, -1) + R(0, 0, 1) + 
  R(0, 1, -3) + R(0, 1, -1) + R(1, -2, 1) + R(1, -2, 3) + 
  R(1, -1, -1) + 3*R(1, -1, 1) + 3*R(1, 0, -1) + R(1, 1, -3) + 
  R(2, -2, 1) + R(2, -1, -1), 
 R(-3, 1, 0) + R(-2, -1, 2) + R(-2, 0, 0) + 2*R(-2, 0, 2) + 
  R(-2, 1, -2) + 3*R(-2, 1, 0) + 2*R(-2, 2, -2) + R(-1, -2, 4) + 
  R(-1, -1, 0) + 4*R(-1, -1, 2) + R(-1, -1, 4) + 9*R(-1, 0, 0) + 
  2*R(-1, 0, 2) + 4*R(-1, 1, -2) + 4*R(-1, 1, 0) + R(-1, 2, -4) + 
  2*R(-1, 2, -2) + R(-1, 3, -4) + 3*R(0, -2, 2) + R(0, -2, 4) + 
  4*R(0, -1, 0) + 7*R(0, -1, 2) + 3*R(0, 0, -2) + 10*R(0, 0, 0) + 
  7*R(0, 1, -2) + R(0, 2, -4) + R(1, -3, 4) + R(1, -2, 0) + 
  4*R(1, -2, 2) + 9*R(1, -1, 0) + R(1, -1, 2) + 4*R(1, 0, -2) + 
  2*R(1, 0, 0) + R(1, 1, -4) + R(1, 1, -2) + R(2, -3, 2) + 
  R(2, -2, 0) + R(2, -2, 2) + R(2, -1, -2) + 2*R(2, -1, 0) + 
  R(2, 0, -2), R(-1, 0, 1) + R(-1, 1, -1) + R(0, -1, 1) + R(0, 0, -1),
  R(-2, 1, 0) + R(-1, -1, 2) + 2*R(-1, 0, 0) + R(-1, 1, -2) + 
  R(-1, 1, 0) + R(-1, 2, -2) + R(0, -1, 0) + R(0, -1, 2) + 
  4*R(0, 0, 0) + 2*R(0, 1, -2) + R(1, -2, 2) + 2*R(1, -1, 0) + 
  R(1, 0, -2) + R(1, 0, 0) + R(1, 1, -2) + R(2, -1, 0), 
 R(-2, 0, 1) + R(-2, 1, -1) + R(-2, 1, 1) + R(-2, 2, -1) + 
  R(-1, -1, 1) + R(-1, -1, 3) + R(-1, 0, -1) + 4*R(-1, 0, 1) + 
  5*R(-1, 1, -1) + R(-1, 2, -3) + R(-1, 2, -1) + R(0, -2, 3) + 
  5*R(0, -1, 1) + 5*R(0, 0, -1) + 3*R(0, 0, 1) + R(0, 1, -3) + 
  3*R(0, 1, -1) + R(0, 2, -3) + R(1, -2, 1) + R(1, -2, 3) + 
  R(1, -1, -1) + 3*R(1, -1, 1) + 4*R(1, 0, -1) + R(1, 1, -3) + 
  R(2, -2, 1) + R(2, -1, -1), 
 R(-1, 0, 1) + R(-1, 1, -1) + R(0, -1, 1) + R(0, 0, -1) + 
  R(1, -1, 1) + R(1, 0, -1), 
 R(-1, 0, 0) + R(0, -1, 2) + R(0, 0, 0) + R(0, 1, -2) + R(1, -1, 0), 
 R(-2, 1, 0) + R(-1, -1, 2) + R(-1, 0, 0) + R(-1, 0, 2) + 
  R(-1, 1, -2) + R(-1, 1, 0) + R(-1, 2, -2) + R(0, -1, 0) + 
  R(0, -1, 2) + 3*R(0, 0, 0) + R(0, 1, -2) + R(1, -2, 2) + 
  R(1, -1, 0) + R(1, 0, -2), 
 R(-1, 0, 1) + R(-1, 1, -1) + R(0, -1, 1) + R(0, 0, -1) + 
  R(0, 1, -1) + R(1, -1, 1) + R(1, 0, -1), 
 R(-2, 1, 0) + R(-1, -1, 2) + R(-1, 0, 0) + R(-1, 0, 2) + 
  R(-1, 1, -2) + R(-1, 1, 0) + R(-1, 2, -2) + R(0, -1, 0) + 
  R(0, -1, 2) + 3*R(0, 0, 0) + R(0, 1, -2) + R(1, -2, 2) + 
  R(1, -1, 0) + R(1, -1, 2) + R(1, 0, -2) + R(1, 0, 0) + R(1, 1, -2) +
   R(2, -1, 0), 
 R(-1, 0, 0) + R(-1, 1, 0) + R(0, -1, 2) + R(0, 0, 0) + R(0, 1, -2) + 
  R(1, -1, 0), R(0, 0, 0)]

svk_dual = rhotwistx = [R(1, 1, 1), 
 R(0, 1, 1) + R(0, 2, 1) + R(1, 0, 3) + R(1, 1, 1) + R(1, 2, -1) + 
  R(2, 0, 1), 
 R(-1, 2, 1) + R(0, 0, 3) + R(0, 1, 1) + R(0, 1, 3) + R(0, 2, -1) + 
  R(0, 2, 1) + R(0, 3, -1) + R(1, 0, 1) + R(1, 0, 3) + 3*R(1, 1, 1) + 
  R(1, 2, -1) + R(2, -1, 3) + R(2, 0, 1) + R(2, 0, 3) + R(2, 1, -1) + 
  R(2, 1, 1) + R(2, 2, -1) + R(3, 0, 1), 
 R(0, 1, 2) + R(0, 2, 0) + R(1, 0, 2) + R(1, 1, 0) + R(1, 2, 0) + 
  R(2, 0, 2) + R(2, 1, 0), 
 R(-1, 2, 1) + R(0, 0, 3) + R(0, 1, 1) + R(0, 1, 3) + R(0, 2, -1) + 
  R(0, 2, 1) + R(0, 3, -1) + R(1, 0, 1) + R(1, 0, 3) + 3*R(1, 1, 1) + 
  R(1, 2, -1) + R(2, -1, 3) + R(2, 0, 1) + R(2, 1, -1), 
 R(0, 1, 1) + R(1, 0, 3) + R(1, 1, 1) + R(1, 2, -1) + R(2, 0, 1), 
 R(0, 1, 2) + R(0, 2, 0) + R(1, 0, 2) + R(1, 1, 0) + R(2, 0, 2) + 
  R(2, 1, 0), 
 R(-1, 1, 2) + R(-1, 2, 0) + R(-1, 2, 2) + R(-1, 3, 0) + R(0, 0, 2) + 
  R(0, 0, 4) + R(0, 1, 0) + 4*R(0, 1, 2) + 5*R(0, 2, 0) + 
  R(0, 3, -2) + R(0, 3, 0) + R(1, -1, 4) + 5*R(1, 0, 2) + 
  5*R(1, 1, 0) + 3*R(1, 1, 2) + R(1, 2, -2) + 3*R(1, 2, 0) + 
  R(1, 3, -2) + R(2, -1, 2) + R(2, -1, 4) + R(2, 0, 0) + 
  3*R(2, 0, 2) + 4*R(2, 1, 0) + R(2, 2, -2) + R(3, -1, 2) + R(3, 0, 0),
  R(-1, 2, 1) + R(0, 0, 3) + 2*R(0, 1, 1) + R(0, 2, -1) + R(0, 2, 1) +
   R(0, 3, -1) + R(1, 0, 1) + R(1, 0, 3) + 4*R(1, 1, 1) + 
  2*R(1, 2, -1) + R(2, -1, 3) + 2*R(2, 0, 1) + R(2, 1, -1) + 
  R(2, 1, 1) + R(2, 2, -1) + R(3, 0, 1), 
 R(0, 1, 2) + R(0, 2, 0) + R(1, 0, 2) + R(1, 1, 0), 
 R(-2, 2, 1) + R(-1, 0, 3) + R(-1, 1, 1) + 2*R(-1, 1, 3) + 
  R(-1, 2, -1) + 3*R(-1, 2, 1) + 2*R(-1, 3, -1) + R(0, -1, 5) + 
  R(0, 0, 1) + 4*R(0, 0, 3) + R(0, 0, 5) + 9*R(0, 1, 1) + 
  2*R(0, 1, 3) + 4*R(0, 2, -1) + 4*R(0, 2, 1) + R(0, 3, -3) + 
  2*R(0, 3, -1) + R(0, 4, -3) + 3*R(1, -1, 3) + R(1, -1, 5) + 
  4*R(1, 0, 1) + 7*R(1, 0, 3) + 3*R(1, 1, -1) + 10*R(1, 1, 1) + 
  7*R(1, 2, -1) + R(1, 3, -3) + R(2, -2, 5) + R(2, -1, 1) + 
  4*R(2, -1, 3) + 9*R(2, 0, 1) + R(2, 0, 3) + 4*R(2, 1, -1) + 
  2*R(2, 1, 1) + R(2, 2, -3) + R(2, 2, -1) + R(3, -2, 3) + 
  R(3, -1, 1) + R(3, -1, 3) + R(3, 0, -1) + 2*R(3, 0, 1) + R(3, 1, -1),
  R(-1, 1, 2) + R(-1, 2, 0) + R(0, 0, 2) + R(0, 0, 4) + R(0, 1, 0) + 
  3*R(0, 1, 2) + 3*R(0, 2, 0) + R(0, 3, -2) + R(1, -1, 4) + 
  5*R(1, 0, 2) + 5*R(1, 1, 0) + R(1, 1, 2) + R(1, 2, -2) + 
  R(1, 2, 0) + R(2, -1, 2) + R(2, -1, 4) + R(2, 0, 0) + 
  3*R(2, 0, 2) + 3*R(2, 1, 0) + R(2, 2, -2) + R(3, -1, 2) + R(3, 0, 0),
  R(-1, 2, 1) + R(0, 0, 3) + 2*R(0, 1, 1) + R(0, 2, -1) + R(1, 0, 1) +
   R(1, 0, 3) + 3*R(1, 1, 1) + R(1, 2, -1) + R(2, -1, 3) + 
  2*R(2, 0, 1) + R(2, 1, -1) + R(3, 0, 1), 
 R(-1, 2, 1) + R(0, 0, 3) + 2*R(0, 1, 1) + R(0, 2, -1) + R(0, 2, 1) + 
  R(0, 3, -1) + R(1, 0, 1) + R(1, 0, 3) + 4*R(1, 1, 1) + 
  2*R(1, 2, -1) + R(2, -1, 3) + 2*R(2, 0, 1) + R(2, 1, -1), 
 R(0, 1, 1) + R(1, 1, 1) + R(1, 2, -1) + R(2, 0, 1), 
 R(0, 2, 0) + R(1, 0, 2) + R(1, 1, 0) + R(2, 1, 0), 
 R(-1, 2, 1) + R(0, 0, 3) + R(0, 1, 1) + R(0, 2, -1) + R(1, 0, 1) + 
  R(1, 1, 1), 
 R(-1, 1, 2) + R(-1, 2, 0) + R(0, 0, 2) + R(0, 0, 4) + R(0, 1, 0) + 
  3*R(0, 1, 2) + 3*R(0, 2, 0) + R(0, 3, -2) + R(1, -1, 4) + 
  4*R(1, 0, 2) + 4*R(1, 1, 0) + R(1, 2, -2) + R(2, -1, 2) + 
  R(2, 0, 0) + R(2, 0, 2) + R(2, 1, 0), 
 R(0, 0, 3) + 2*R(0, 1, 1) + R(0, 2, -1) + R(1, 0, 1) + R(1, 0, 3) + 
  2*R(1, 1, 1) + R(1, 2, -1) + R(2, -1, 3) + 2*R(2, 0, 1) + 
  R(2, 1, -1), R(0, 1, 1) + R(2, 0, 1), 
 R(0, 2, 0) + R(1, 0, 2) + R(1, 1, 0), 
 R(-2, 2, 1) + R(-1, 0, 3) + R(-1, 1, 1) + R(-1, 1, 3) + 
  R(-1, 2, -1) + 2*R(-1, 2, 1) + 2*R(-1, 3, -1) + R(0, 0, 1) + 
  2*R(0, 0, 3) + 7*R(0, 1, 1) + R(0, 1, 3) + 3*R(0, 2, -1) + 
  3*R(0, 2, 1) + R(0, 3, -3) + 2*R(0, 3, -1) + R(0, 4, -3) + 
  2*R(1, -1, 3) + 3*R(1, 0, 1) + 3*R(1, 0, 3) + 3*R(1, 1, -1) + 
  7*R(1, 1, 1) + 7*R(1, 2, -1) + R(1, 3, -3) + R(2, -1, 1) + 
  2*R(2, -1, 3) + 7*R(2, 0, 1) + 4*R(2, 1, -1) + R(2, 1, 1) + 
  R(2, 2, -3) + R(2, 2, -1) + R(3, -2, 3) + R(3, -1, 1) + 
  R(3, 0, -1) + R(3, 0, 1) + R(3, 1, -1), 
 R(-1, 2, 0) + R(0, 0, 2) + R(0, 1, 0) + R(0, 1, 2) + 2*R(0, 2, 0) + 
  R(0, 3, -2) + 2*R(1, 0, 2) + 4*R(1, 1, 0) + R(1, 2, -2) + 
  R(1, 2, 0) + R(2, -1, 2) + R(2, 0, 0) + R(2, 0, 2) + 2*R(2, 1, 0) + 
  R(2, 2, -2) + R(3, 0, 0), 
 R(-2, 3, 0) + 2*R(-1, 1, 2) + 2*R(-1, 2, 0) + R(-1, 3, -2) + 
  R(0, -1, 4) + 2*R(0, 0, 2) + R(0, 0, 4) + 3*R(0, 1, 0) + 
  3*R(0, 1, 2) + R(0, 2, -2) + 4*R(0, 2, 0) + 
  2*(R(0, 2, 0) + R(0, 3, -2)) + R(1, -1, 2) + R(1, -1, 4) + 
  R(1, 0, 0) + 7*R(1, 0, 2) + 5*R(1, 1, 0) + 2*R(1, 1, 2) + 
  3*(R(1, 1, 0) + R(1, 2, -2)) + 2*R(1, 2, 0) + R(1, 3, -2) + 
  R(2, -2, 4) + 2*R(2, -1, 2) + R(2, -1, 4) + 3*R(2, 0, 0) + 
  3*R(2, 0, 2) + R(2, 1, -2) + 4*R(2, 1, 0) + 
  2*(R(2, 1, 0) + R(2, 2, -2)) + 2*R(3, -1, 2) + 2*R(3, 0, 0) + 
  R(3, 1, -2) + R(4, 0, 0), R(0, 1, 1), 
 R(0, 0, 3) + R(0, 1, 1) + R(0, 2, -1) + R(1, 0, 1), 
 R(1, 0, 2) + R(1, 1, 0), 
 R(-1, 0, 3) + R(-1, 1, 1) + R(-1, 2, -1) + R(0, 0, 1) + R(0, 0, 3) + 
  3*R(0, 1, 1) + R(0, 2, -1) + 2*R(1, -1, 3) + 3*R(1, 0, 1) + 
  R(1, 0, 3) + 2*R(1, 1, -1) + R(1, 1, 1) + R(1, 2, -1) + 
  R(2, -1, 1) + R(2, -1, 3) + 3*R(2, 0, 1) + R(2, 1, -1) + 
  R(3, -2, 3) + R(3, -1, 1) + R(3, 0, -1), 
 R(-2, 3, 0) + 2*R(-1, 1, 2) + 2*R(-1, 2, 0) + R(-1, 3, -2) + 
  R(0, -1, 4) + 2*R(0, 0, 2) + 3*R(0, 1, 0) + R(0, 2, -2) + 
  R(0, 2, 0) + R(1, -1, 2) + R(1, 0, 0) + R(1, 0, 2) + R(1, 1, 0), 
 R(-1, 2, 0) + R(0, 0, 2) + R(0, 1, 0) + R(0, 1, 2) + 2*R(0, 2, 0) + 
  R(0, 3, -2) + 2*R(1, 0, 2) + 3*R(1, 1, 0) + R(1, 2, -2) + 
  R(2, -1, 2) + R(2, 0, 0) + R(2, 1, 0), 
 R(0, 1, 1) + R(0, 2, -1) + R(1, 0, 1) + R(1, 1, 1) + R(1, 2, -1) + 
  R(2, 0, 1) + R(2, 1, -1), 
 R(-1, 2, 0) + R(0, 0, 2) + R(0, 1, 0) + R(1, 0, 2) + 2*R(1, 1, 0) + 
  R(2, -1, 2) + R(2, 0, 0) + R(3, 0, 0), 
 R(-1, 0, 3) + R(-1, 1, 1) + R(-1, 2, -1) + R(0, 0, 1) + R(0, 0, 3) + 
  2*R(0, 1, 1) + R(0, 2, -1) + R(1, -1, 3) + 2*R(1, 0, 1) + 
  R(1, 1, -1), 
 R(-1, 1, 2) + R(-1, 2, 0) + R(0, -1, 4) + 2*R(0, 0, 2) + 
  2*R(0, 1, 0) + R(0, 2, -2) + R(1, -1, 2) + R(1, 0, 0) + R(1, 0, 2) +
   R(1, 1, 0), 
 R(0, 0, 2) + R(0, 1, 0) + R(1, 0, 2) + R(1, 1, 0) + R(2, -1, 2) + 
  R(2, 0, 0), R(-1, 2, 0) + R(0, 0, 2) + R(0, 1, 0), 
 R(0, 1, 1) + R(0, 2, -1) + R(1, 0, 1), R(1, 1, 0), 
 R(-1, 1, 1) + R(-1, 2, -1) + R(0, 0, 1) + 2*R(0, 1, 1) + 
  R(0, 2, -1) + R(1, -1, 3) + 3*R(1, 0, 1) + 2*R(1, 1, -1) + 
  R(2, -1, 1) + 2*R(2, 0, 1) + R(2, 1, -1) + R(3, -1, 1) + R(3, 0, -1),
  R(0, 0, 2) + R(0, 1, 0), R(1, 0, 1), 
 R(-1, 1, 1) + R(-1, 2, -1) + R(0, 0, 1) + R(0, 1, 1) + R(0, 2, -1) + 
  R(1, 0, 1) + R(1, 1, -1), 
 R(-1, 2, 0) + R(0, 0, 2) + R(0, 1, 0) + R(0, 2, -2) + R(1, 0, 0) + 
  R(1, 1, 0), R(0, 1, 0) + R(2, 0, 0), R(0, 0, 1), R(0, 1, 0), 
 R(1, 0, 0), R(0, 0, 0)]

element_list = [
 [3, 2, 3, 2, 1, 2, 3, 2, 1],
 [3, 2, 3, 2, 1, 2, 3, 2],
 [3, 2, 3, 1, 2, 3, 2, 1],
 [2, 3, 2, 1, 2, 3, 2, 1],
 [3, 2, 3, 1, 2, 3, 2],
 [3, 2, 3, 2, 1, 2, 3],
 [2, 3, 1, 2, 3, 2, 1],
 [2, 3, 2, 1, 2, 3, 2],
 [3, 2, 1, 2, 3, 2, 1],
 [2, 3, 1, 2, 3, 2],
 [3, 2, 3, 1, 2, 3],
 [2, 3, 2, 1, 2, 3],
 [3, 1, 2, 3, 2, 1],
 [3, 2, 1, 2, 3, 2],
 [3, 2, 3, 2, 1, 2],
 [2, 1, 2, 3, 2, 1],
 [3, 1, 2, 3, 2],
 [2, 3, 1, 2, 3],
 [3, 2, 1, 2, 3],
 [3, 2, 3, 2, 1],
 [2, 1, 2, 3, 2],
 [3, 2, 3, 1, 2],
 [2, 3, 2, 1, 2],
 [1, 2, 3, 2, 1],
 [3, 2, 3, 2],
 [3, 1, 2, 3],
 [2, 1, 2, 3],
 [3, 2, 3, 1],
 [1, 2, 3, 2],
 [2, 3, 1, 2],
 [3, 2, 1, 2],
 [2, 3, 2, 1],
 [3, 2, 3],
 [1, 2, 3],
 [2, 3, 1],
 [2, 3, 2],
 [3, 1, 2],
 [2, 1, 2],
 [3, 2, 1],
 [2, 3],
 [3, 1],
 [3, 2],
 [1, 2],
 [2, 1],
 [3],
 [2],
 [1],
 []
]

stein = [R(-1, -1, -1),
 R(0, -1, -1),
 R(-1, 0, -1),
 R(-1, -1, 0),
 R(1, -1, -1),
 R(-1, 1, -3),
 R(-2, 1, -2),
 R(0, -1, 0),
 R(-1, -1, 1),
 R(2, -1, -2),
 R(0, 0, -1),
 R(-1, 1, -2),
 R(-2, 1, -1),
 R(1, -2, 1),
 R(-1, -2, 3),
 R(-2, -1, 2),
 R(2, -1, -1),
 R(1, 0, -2),
 R(-1, 2, -3),
 R(-3, 2, -1),
 R(2, -3, 2),
 R(0, -1, 1),
 R(-1, -1, 2),
 R(-1, 0, 0),
 R(3, -1, -1),
 R(1, 1, -3),
 R(-1, 3, -4),
 R(-1, 1, -1),
 R(1, -1, 0),
 R(1, -2, 2),
 R(-1, -1, 3),
 R(-2, 1, 0),
 R(1, 0, -1),
 R(0, 1, -2),
 R(-1, 2, -2),
 R(2, -1, 0),
 R(1, -2, 3),
 R(-1, -1, 4),
 R(-1, 0, 1),
 R(1, 1, -2),
 R(-1, 2, -1),
 R(1, -1, 1),
 R(0, -1, 2),
 R(-1, 0, 2),
 R(0, 1, -1),
 R(1, -1, 2),
 R(-1, 1, 0),
 R(0, 0, 0)]

svk_dual_dict = {}
svk_dict = {}
col_dict = {}
stein_dict = {}
S = list(W.simple_reflections())
for i in range(len(element_list)):
    a = s1*s1
    for j in range(len(element_list[i])):
        a = a * S[element_list[i][j]-1]
    svk_dict[a] = svk[i]
    svk_dual_dict[a] = (-1)^(a.length()) * svk_dual[i]
    stein_dict[a] = stein[i]

svk_q_dict = {}
for i in range(len(W)):
    svk_q_dict[W[i]] = svk_dict[W[i]].scale(q)
svk_q_dual_dict = {}
for i in range(len(W)):
    svk_q_dual_dict[W[i]] = svk_dual_dict[W[i]].scale(q)

print("Landed")
# Out:
# Landed

# %%
for w in W:
    for y in W:
        a = woke_pairing(stein_dict[w], stein_dict[y])
        if a != 0:
            print(w, y, a)
# Out:
# 1 s3*s2*s3*s1*s2*s3*s1*s2*s1 -B3(0,0,0)
# s3 s1*s2*s3*s1 B3(0,0,0)
# s3*s2 s1*s2*s3*s1*s2 -B3(0,0,0)
# s3*s2*s1 s1*s2*s1 B3(0,0,0)
# s3*s2*s1 s1*s2*s3*s1*s2*s1 B3(0,0,0)
# s2 s3*s1*s2 -B3(0,0,0)
# s2 s3*s2*s3*s2 -B3(0,0,0)
# s2*s3 s3*s1*s2*s3 B3(0,0,0)
# s2*s3*s2 s3*s2*s3*s1*s2*s3*s1*s2*s1 B3(0,0,0)
# s2*s3*s2 s3*s1*s2*s3*s2 -B3(0,0,0)
# s2*s3*s2*s1 s3*s1*s2*s3*s2*s1 B3(0,0,0)
# s2*s3*s2*s1 s3*s2*s3*s1*s2*s3*s1 -B3(0,0,0)
# s2*s3*s2*s1 s3*s2*s3*s1*s2*s1 B3(0,0,0)
# s2*s1 s3*s1*s2*s1 B3(0,0,0)
# s2*s1 s3*s2*s3*s1*s2*s1 -B3(0,0,0)
# s2*s1 s3*s2*s3*s2*s1 B3(0,0,0)
# s2*s3*s1 s3*s2*s3*s1*s2*s3*s1*s2*s1 B3(0,0,0)
# s2*s3*s1 s3*s1*s2*s3*s1 -B3(0,0,0)
# s2*s3*s1 s3*s1 -B3(0,0,0)
# s2*s3*s1 s3*s2*s3*s1*s2*s3*s1 B3(0,0,0)
# s2*s3*s1*s2 s3*s1*s2*s3*s1*s2 B3(0,0,0)
# s2*s3*s1*s2 s3*s1*s2 B3(0,0,0)
# s2*s3*s1*s2 s3*s2*s3*s1*s2*s3*s1*s2 -B3(0,0,0)
# s2*s3*s1*s2 s3*s2*s3*s2 B3(0,0,0)
# s2*s3*s1*s2*s1 s3*s2*s3*s1*s2*s3*s1*s2*s1 B3(1,0,0)
# s2*s3*s1*s2*s1 s3*s1*s2*s3*s1*s2*s1 -B3(0,0,0)
# ...

# %%
print(svk_dict)
# Out:
# {s3*s2*s3*s1*s2*s3*s1*s2*s1: b3(-1,-1,-1), s3*s2*s3*s1*s2*s3*s1*s2: b3(0,-1,-1), s3*s2*s3*s1*s2*s3*s2*s1: b3(-1,0,-1), s2*s3*s1*s2*s3*s1*s2*s1: b3(-1,-1,0), s3*s2*s3*s1*s2*s3*s2: b3(-1,0,-1) + b3(1,-1,-1), s3*s2*s3*s1*s2*s3*s1: b3(0,-1,-1) + b3(-1,1,-3) + b3(-1,0,-1) + b3(-1,-1,1) + b3(-2,1,-1) + b3(0,0,-1), s2*s3*s1*s2*s3*s2*s1: b3(-2,0,0) + b3(-1,-1,0) + b3(-2,1,-2) + b3(-1,0,0) + b3(0,-1,0) + b3(0,0,-2) + b3(-1,1,-2), s2*s3*s1*s2*s3*s1*s2: b3(0,-1,0), s3*s1*s2*s3*s1*s2*s1: b3(-1,0,-1) + b3(-1,-1,1), s2*s3*s1*s2*s3*s2: b3(-2,0,0) + b3(-1,-1,0) + b3(-2,1,-2) + 2*b3(-1,0,0) + b3(1,-2,0) + 3*b3(0,-1,0) + 2*b3(0,0,-2) + b3(0,-2,2) + b3(-1,1,-2) + b3(2,-2,0) + b3(2,-1,-2) + 2*b3(1,-1,0) + b3(1,0,-2), s3*s2*s3*s1*s2*s3: b3(0,0,-1), s2*s3*s1*s2*s3*s1: b3(-1,0,0) + b3(0,-1,0) + b3(-1,1,-2), s3*s1*s2*s3*s2*s1: b3(-1,0,-1) + b3(-1,-1,1) + b3(-2,1,-1), s3*s1*s2*s3*s1*s2: b3(-1,0,-1) + b3(-1,-1,1) + b3(1,-1,-1) + b3(1,-2,1) + b3(0,0,-1) + b3(0,-1,1), s3*s2*s3*s1*s2*s1: b3(0,-1,-1) + b3(0,-2,1)
# ...

# %%
# The dual is like this
#If all true, we good and it's the correct dual!
for w in W:
    for y in W:
        #if pairing(svk_dict[w], svk_dual_dict[y]) != 0:
        if pairing(svk_dual_dict[w], svk_dict[y]) != 0:
            print(w == y, w, y)
            #print(pairing(svk_dict[w], svk_dual_dict[y]))
# Out:
# True 1 1
# True s3 s3
# True s3*s2 s3*s2
# True s3*s2*s1 s3*s2*s1
# True s2 s2
# True s2*s3 s2*s3
# True s2*s3*s2 s2*s3*s2
# True s2*s3*s2*s1 s2*s3*s2*s1
# True s2*s1 s2*s1
# True s2*s3*s1 s2*s3*s1
# True s2*s3*s1*s2 s2*s3*s1*s2
# True s2*s3*s1*s2*s1 s2*s3*s1*s2*s1
# True s3*s2*s3*s1*s2*s3*s1*s2*s1 s3*s2*s3*s1*s2*s3*s1*s2*s1
# True s2*s3*s1*s2*s3*s1*s2*s1 s2*s3*s1*s2*s3*s1*s2*s1
# True s2*s3*s1*s2*s3*s2*s1 s2*s3*s1*s2*s3*s2*s1
# True s2*s3*s1*s2*s3*s2 s2*s3*s1*s2*s3*s2
# True s3*s2*s3*s1*s2*s3*s2*s1 s3*s2*s3*s1*s2*s3*s2*s1
# True s3*s1*s2*s3*s1*s2*s1 s3*s1*s2*s3*s1*s2*s1
# True s3*s1*s2*s3*s2*s1 s3*s1*s2*s3*s2*s1
# True s3*s1*s2*s3*s2 s3*s1*s2*s3*s2
# True s3*s2*s3*s1*s2*s3*s2 s3*s2*s3*s1*s2*s3*s2
# True s3*s1*s2*s3*s1*s2 s3*s1*s2*s3*s1*s2
# True s3*s1*s2*s3*s1 s3*s1*s2*s3*s1
# True s3*s1*s2*s3 s3*s1*s2*s3
# True s1 s1
# True s3*s1 s3*s1
# True s3*s1*s2 s3*s1*s2
# True s3*s1*s2*s1 s3*s1*s2*s1
# True s1*s2 s1*s2
# True s1*s2*s3 s1*s2*s3
# True s1*s2*s3*s2 s1*s2*s3*s2
# ...

# %%
def nqpair(w, y):
    #new/normalized q_pairing
    return pairing(svk_dual_dict[w], svk_dict[w])* pairing(svk_dual_dict[w], svk_q_dict[w])

table = []

Mw = {}

sumtot = 0
for w in W:
    table.append([str(w), str(nqpair(w, w))])
    sumtot += nqpair(w,w)

for row in table:
    print('| {:25} | {:1}'.format(*row))

print("--------------------------------------------------------------------------------------------")
print(sumtot)
# Out:
# | 1                         | B3(0,0,0)
# | s3                        | B3(0,0,28)
# | s3*s2                     | B3(0,0,26) + B3(1,0,26) + B3(0,0,28)
# | s3*s2*s1                  | -B3(0,0,24) - B3(0,1,24) + B3(1,0,26) + B3(0,0,28)
# | s2                        | B3(0,28,0)
# | s2*s3                     | -B3(26,0,0) - B3(27,0,0) - B3(0,26,2) + B3(1,27,0) + B3(0,28,0)
# | s2*s3*s2                  | -B3(26,0,0) - B3(27,0,0) - B3(0,26,2) + B3(0,28,0)
# | s2*s3*s2*s1               | -B3(27,0,0) + B3(1,26,0) - B3(0,26,2) + B3(0,28,0)
# | s2*s1                     | -B3(27,0,0) + B3(1,26,0) - B3(0,26,2) + B3(0,28,0)
# | s2*s3*s1                  | B3(0,27,0) + B3(0,26,2) + B3(1,27,0) + B3(0,28,0)
# | s2*s3*s1*s2               | -B3(26,0,0) - B3(27,0,0) + B3(1,26,0) + B3(1,27,0) + B3(0,28,0)
# | s2*s3*s1*s2*s1            | B3(0,26,0) + B3(0,27,0) + B3(0,26,2) + B3(0,28,0)
# | s3*s2*s3*s1*s2*s3*s1*s2*s1 | B3(28,28,28)
# | s2*s3*s1*s2*s3*s1*s2*s1   | B3(28,28,0)
# ...

# %%
# The dual is like this
#If all true, we good and it's the correct dual!
m = []
for w in W:
    lw = []
    for y in W:
        e = 0
        #if pairing(svk_dict[w], svk_dual_dict[y]) != 0:
        if pairing(stein_dict[w], svk_dict[y]) != 0:
            e = 1
            #print(pairing(svk_dict[w], svk_dual_dict[y]))
        lw.append(e)
    m.append(lw)
print(matrix(m).determinant())
# Out:
# 0
